# %%
# Loading libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the data
df = pd.read_csv('C:/Users/Admin/Desktop/Saiprakash/DT/HR Analytics.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#head returns the first 5 rows 
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#tail returns the last 5 rows 
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
#Checking for shape of the dataset(ie.,number of rows and columns of the dataset.)
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# There are 1470 rows and 35 columns present in this dataset

# %%
#Checking the columns
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#Checking the data types of each column
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# In this dataset,there are more number of integer datatypes and less number of object datatypes

# %%
#Checking the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# Observations from the information of the dataset includes :
#
# ==> There are 1470 rows and 35 columns in the dataset.
#
#
# ==> There are no missing values in the dataset.

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Obervations:
#
#     ==> EmployeeCount has all the summary statistics least.
#
#     ==> The age range of employees is between 18 and 60.
#
#     ==> The least employees distance from home is 1 and that of  longest is about 29.
#
#     ==> The standard hours are kept upto 80 hours.

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Checking for unique values
df['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# There are two categories in attrition (yes and no)

# %%
#Checking for Missing Values

# %%
#checking for the sum of null values if any
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Visualizing the null values using heatmap
sns.heatmap(df.isnull(),cmap = 'Blues')

# %% [markdown]
# # To check the Correlation

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
plt.figure(figsize=(22,18))
sns.heatmap(df.corr(),annot = True,cmap='Blues')

# %% [markdown]
#  Observations:
#
#     ==>JobLevel is in high correlation with MonthlyIncome.
#
#     ==>Years at company is in neagtive correlation with NumCompanies

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize=[10,8])
sns.countplot(x = 'Attrition', data = df)

# %% [markdown]
# From the count plot,we observe that Attrition (loss of employees) is less for yes,that is loss of employees is less.

# %%
sns.countplot(df.OverTime)

# %% [markdown]
# From the countplot,Most of the employees doesn't prefer overtime.

# %%
sns.countplot(df.Gender)

# %% [markdown]
# Majority of the employees are male.

# %%
plt.figure(figsize=[10,8])
sns.countplot(x = 'BusinessTravel', data = df)

# %% [markdown]
# From the barplot,least people opt for BusinessTravel.Travel_Rarely employees are more.

# %%
sns.violinplot(df['NumCompaniesWorked'])

# %% [markdown]
# Most of the employees worked for 1 to 2 companies.

# %%
plt.figure(figsize=(28,10))
sns.countplot(data=df, x='Education', hue='MaritalStatus')
plt.legend(loc='upper right')
plt.xticks(rotation = 90);

# %% [markdown]
# Most of the employees in education category are married.

# %%
sns.violinplot(df['MonthlyIncome'])

# %% [markdown]
# Most of the employees monthly income is in the range of 2000 to 8000.

# %%
sns.violinplot(df['JobSatisfaction'])

# %% [markdown]
# From the above scatterplot,most employees have jobsatisfaction level 4.

# %% [markdown]
# # Bivariate Analysis

# %%
sns.barplot( x = 'Attrition',y = 'JobLevel', data = df)

# %%
sns.barplot( x = 'Attrition',y = 'EmployeeCount', data = df)

# %% [markdown]
# There is equal number of attrition.So,we can say that as the employees leaving,the company recruits another.

# %%
sns.barplot(x ='YearsSinceLastPromotion', y = 'PercentSalaryHike',hue = 'Attrition' ,data = df)

# %% [markdown]
# From the above barplot,When the employee who is having 10 years of experience will have high chance of salary hike.

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='OverTime',y='YearsAtCompany', data=df,palette='plasma' )

# %% [markdown]
# Employees doing overtime are almost same upto 7 years

# %%
plt.figure(figsize=(8,6))
sns.barplot(x= 'Attrition',y='TrainingTimesLastYear', data=df,palette='plasma' )

# %% [markdown]
# From the above barplot,we observe that employees who took training more times has less scope of leaving the job.

# %% [markdown]
# # Plotting Outliers

# %%
df.plot(kind='box', subplots=True, layout=(10,5), figsize=(12,12))
plt.show()

# %% [markdown]
# From the above boxplots,it is clear that outliers are present.

# %% [markdown]
# # To check the distribution of skewness

# %%
collist=df.columns.values
ncol=35
nrow=90

# %%
df.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# ...

# %%
#Less skewness is present

# %% [markdown]
# # Removing Outliers

# %%
#Removing for outliers using IQR
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Age                            13.00
# DailyRate                     692.00
# DistanceFromHome               12.00
# Education                       2.00
# EmployeeCount                   0.00
# EmployeeNumber               1064.50
# EnvironmentSatisfaction         2.00
# HourlyRate                     35.75
# JobInvolvement                  1.00
# JobLevel                        2.00
# JobSatisfaction                 2.00
# MonthlyIncome                5468.00
# MonthlyRate                 12414.50
# NumCompaniesWorked              3.00
# PercentSalaryHike               6.00
# PerformanceRating               0.00
# RelationshipSatisfaction        2.00
# StandardHours                   0.00
# StockOptionLevel                1.00
# TotalWorkingYears               9.00
# TrainingTimesLastYear           1.00
# WorkLifeBalance                 1.00
# YearsAtCompany                  6.00
# YearsInCurrentRole              5.00
# YearsSinceLastPromotion         3.00
# ...

# %%
(df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))
df_o = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
df_o
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
print(df.shape,'\t',df_o.shape)
# Out:
# (1470, 35) 	 (779, 35)

# %% [markdown]
# 1470 rows have reduced to 779 rows.So,outliers are removed.

# %%
df = df_o
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Model Training

# %%
#Copying numerical columns
df_num = df[['Age','DailyRate','DistanceFromHome','EnvironmentSatisfaction', 'HourlyRate','JobInvolvement', 'JobLevel','JobSatisfaction','RelationshipSatisfaction','StockOptionLevel','TrainingTimesLastYear']].copy()
df_num.head()
# Out:
#     Age  DailyRate  DistanceFromHome  EnvironmentSatisfaction  HourlyRate  \
# 2    37       1373                 2                        4          92
# 3    33       1392                 3                        4          56
# 5    32       1005                 2                        4          79
# 9    36       1299                27                        3          94
# 11   29        153                15                        4          49
#
#     JobInvolvement  JobLevel  JobSatisfaction  RelationshipSatisfaction  \
# 2                2         1                3                         2
# 3                3         1                3                         3
# 5                3         1                4                         3
# 9                3         2                3                         2
# 11               2         2                3                         4
#
#     StockOptionLevel  TrainingTimesLastYear
# ...

# %%
#Copying categorical data
df_cat = df[['Attrition', 'BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','Over18', 'OverTime']].copy()
df_cat.head()
# Out:
#    Attrition     BusinessTravel              Department EducationField  \
# 2        Yes      Travel_Rarely  Research & Development          Other
# 3         No  Travel_Frequently  Research & Development  Life Sciences
# 5         No  Travel_Frequently  Research & Development  Life Sciences
# 9         No      Travel_Rarely  Research & Development        Medical
# 11        No      Travel_Rarely  Research & Development  Life Sciences
#
#     Gender                    JobRole MaritalStatus Over18 OverTime
# 2     Male      Laboratory Technician        Single      Y      Yes
# 3   Female         Research Scientist       Married      Y      Yes
# 5     Male      Laboratory Technician        Single      Y       No
# 9     Male  Healthcare Representative       Married      Y       No
# 11  Female      Laboratory Technician        Single      Y      Yes

# %%
#Assigning target variable(Attrition) yes with 1 and no with 0
Num_val = {'Yes':1, 'No':0}
df_cat['Attrition'] = df_cat['Attrition'].apply(lambda x: Num_val[x])
df_cat.head()
# Out:
#     Attrition     BusinessTravel              Department EducationField  \
# 2           1      Travel_Rarely  Research & Development          Other
# 3           0  Travel_Frequently  Research & Development  Life Sciences
# 5           0  Travel_Frequently  Research & Development  Life Sciences
# 9           0      Travel_Rarely  Research & Development        Medical
# 11          0      Travel_Rarely  Research & Development  Life Sciences
#
#     Gender                    JobRole MaritalStatus Over18 OverTime
# 2     Male      Laboratory Technician        Single      Y      Yes
# 3   Female         Research Scientist       Married      Y      Yes
# 5     Male      Laboratory Technician        Single      Y       No
# 9     Male  Healthcare Representative       Married      Y       No
# 11  Female      Laboratory Technician        Single      Y      Yes

# %%
df_cat = pd.get_dummies(df_cat)
df_cat.head()
# Out:
#     Attrition  BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 2           1                          0                                 0
# 3           0                          0                                 1
# 5           0                          0                                 1
# 9           0                          0                                 0
# 11          0                          0                                 0
#
#     BusinessTravel_Travel_Rarely  Department_Human Resources  \
# 2                              1                           0
# 3                              0                           0
# 5                              0                           0
# 9                              1                           0
# 11                             1                           0
#
#     Department_Research & Development  Department_Sales  \
# 2                                   1                 0
# ...

# %%
#concatinating both numerical and categorical columns
df = pd.concat([df_num, df_cat], axis=1)
df.head()
# Out:
#     Age  DailyRate  DistanceFromHome  EnvironmentSatisfaction  HourlyRate  \
# 2    37       1373                 2                        4          92
# 3    33       1392                 3                        4          56
# 5    32       1005                 2                        4          79
# 9    36       1299                27                        3          94
# 11   29        153                15                        4          49
#
#     JobInvolvement  JobLevel  JobSatisfaction  RelationshipSatisfaction  \
# 2                2         1                3                         2
# 3                3         1                3                         3
# 5                3         1                4                         3
# 9                3         2                3                         2
# 11               2         2                3                         4
#
#     StockOptionLevel  ...  JobRole_Research Director  \
# ...

# %%
#Seperating into input and output variables
x = df.drop('Attrition', axis=1)  
y = df['Attrition']

# %%
#Splitting input and output variable into train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.20, random_state = 42)

# %%
print(x_train.shape,'\t',x_test.shape)

print(y_train.shape,'\t',y_test.shape)
# Out:
# (623, 40) 	 (156, 40)
# (623,) 	 (156,)

# %%
#importing algorithms
import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

model = [LogisticRegression(),MultinomialNB(),DecisionTreeClassifier(),KNeighborsClassifier(),SVC()] 

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred=m.predict(x_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    print('==============================================================================================')
    print('\n')
# Out:
# Accuracy score of LogisticRegression() is:
# 0.8653846153846154
# [[125   6]
#  [ 15  10]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       131
#            1       0.62      0.40      0.49        25
#
#     accuracy                           0.87       156
#    macro avg       0.76      0.68      0.71       156
# weighted avg       0.85      0.87      0.85       156
#
# ...
#
#
# Accuracy score of MultinomialNB() is:
# 0.6794871794871795
# [[91 40]
#  [10 15]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.69      0.78       131
#            1       0.27      0.60      0.37        25
#
#     accuracy                           0.68       156
#    macro avg       0.59      0.65      0.58       156
# weighted avg       0.80      0.68      0.72       156
#
# ...
#
#
# Accuracy score of DecisionTreeClassifier() is:
# 0.8205128205128205
# [[113  18]
#  [ 10  15]]
# ...

# %%
#Using Ensemble methods to improve accuracy

# %%
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier

model = [RandomForestClassifier(),AdaBoostClassifier()] 
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred=m.predict(x_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    print('==============================================================================================')
    print('\n')
# Out:
# Accuracy score of RandomForestClassifier() is:
# 0.8717948717948718
# [[131   0]
#  [ 20   5]]
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       131
#            1       1.00      0.20      0.33        25
#
#     accuracy                           0.87       156
#    macro avg       0.93      0.60      0.63       156
# weighted avg       0.89      0.87      0.83       156
#
# ...
#
#
# Accuracy score of AdaBoostClassifier() is:
# 0.8461538461538461
# [[122   9]
#  [ 15  10]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       131
#            1       0.53      0.40      0.45        25
#
#     accuracy                           0.85       156
#    macro avg       0.71      0.67      0.68       156
# weighted avg       0.83      0.85      0.84       156
#
# ...

# %% [markdown]
# RandomForestClassifier model has best accuracy than all models

# %% [markdown]
# # AUC ROC CURVE

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred_prob=rfc.predict_proba(x_test)[:,1]
y_pred_prob
# Out:
# array([0.05, 0.05, 0.25, 0.08, 0.15, 0.37, 0.47, 0.13, 0.43, 0.34, 0.06,
#        0.31, 0.27, 0.28, 0.18, 0.2 , 0.26, 0.27, 0.23, 0.13, 0.27, 0.04,
#        0.11, 0.24, 0.07, 0.12, 0.15, 0.09, 0.09, 0.35, 0.11, 0.3 , 0.22,
#        0.68, 0.11, 0.38, 0.42, 0.07, 0.09, 0.09, 0.35, 0.37, 0.38, 0.02,
#        0.  , 0.28, 0.11, 0.16, 0.32, 0.42, 0.18, 0.33, 0.11, 0.29, 0.14,
#        0.19, 0.36, 0.29, 0.16, 0.17, 0.15, 0.18, 0.16, 0.09, 0.3 , 0.03,
#        0.15, 0.05, 0.65, 0.11, 0.37, 0.12, 0.02, 0.71, 0.18, 0.2 , 0.15,
#        0.27, 0.23, 0.1 , 0.4 , 0.43, 0.  , 0.23, 0.14, 0.23, 0.31, 0.04,
#        0.11, 0.05, 0.06, 0.35, 0.29, 0.07, 0.34, 0.28, 0.14, 0.11, 0.04,
#        0.11, 0.26, 0.16, 0.27, 0.24, 0.03, 0.21, 0.23, 0.15, 0.53, 0.25,
#        0.26, 0.18, 0.13, 0.24, 0.07, 0.51, 0.17, 0.23, 0.06, 0.1 , 0.33,
#        0.09, 0.39, 0.21, 0.1 , 0.04, 0.05, 0.19, 0.23, 0.43, 0.29, 0.1 ,
#        0.24, 0.58, 0.36, 0.2 , 0.13, 0.37, 0.05, 0.22, 0.13, 0.18, 0.35,
# ...

# %%
fpr,tpr,threshold=roc_curve(y_test,y_pred_prob)

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='RandomForestClassifier()')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Saving the best model in a pickle file

# %%
#importing joblib
import joblib

rfc = RandomForestClassifier()
#saving the model in a pickle file
joblib.dump(rfc,'HR.pkl')
# Out:
# ['HR.pkl']

# %%
Submission1=pd.DataFrame(pred)
Submission1.head(2)
# Out:
#    0
# 0  0
# 1  0

# %%
#saving the Submission1 file in csv
filename = 'Submission1.csv'
Submission1.to_csv(filename,index = False)

print('saved File:',filename)
# Out:
# saved File: Submission1.csv
